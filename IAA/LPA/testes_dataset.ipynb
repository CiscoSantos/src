# %% [markdown]
# Testes com os metodos, funções e objetos mostrados nos exercicios praticos de LPA.

# %%
# Importando as bibliotecas que serão usadas no exercicio;
import  pandas as pd

import  seaborn as sb

import matplotlib.pyplot as mtp

import warnings
warnings.filterwarnings('ignore')

# %%
dados = pd.read_csv('dados_salarial_funcionarios.csv')

# %%
dados.head()
# Out:
#    Idade     Genero            Nivel Ensino  \
# 0     38  Masculino           Pós-graduação
# 1     39  Masculino           Pós-graduação
# 2     30  Masculino           Pós-graduação
# 3     38   Feminino           Pós-graduação
# 4     36  Masculino           Pós-graduação
# 5     24  Masculino  Estudante de Graduação
# 6     51  Masculino           Pós-graduação
# 7     39  Masculino   Graduação/Bacharelado
# 8     32   Feminino           Pós-graduação
# 9     34   Feminino           Pós-graduação
#
#                                        Area Formacao  \
# 0                                   Química / Física
# 1  Economia/ Administração / Contabilidade / Fina...
# 2  Computação / Engenharia de Software / Sistemas...
# 3                                             Outras
# 4                                 Outras Engenharias
# 5                                 Outras Engenharias
# 6  Computação / Engenharia de Software / Sistemas...
# ...

# %%
dados.shape
# Out:
# (1385, 10)
